# %%
import handcalcs.render
from handcalcs import render
handcalcs.set_option("display_precision", 3)
handcalcs.set_option("decimal_separator", ",")
from handcalcs.decorator import handcalc

from math import pi, sqrt, sin, cos, tan, atan, tanh, cosh, sinh
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle, FancyBboxPatch
import matplotlib.patches as mpatches

import forallpeople
forallpeople.environment('structural', top_level=True)

# Configuración para gráficos export-ready
plt.rcParams['figure.dpi'] = 150
plt.rcParams['savefig.dpi'] = 300
plt.rcParams['font.size'] = 10
plt.rcParams['axes.labelsize'] = 11
plt.rcParams['axes.titlesize'] = 12
plt.rcParams['legend.fontsize'] = 9
plt.rcParams['figure.titlesize'] = 13

# %% [markdown]
# # A_s min Losas

# %%
# %%render params 1
#
# h = 600 * mm
# b = 1000 * mm
# rho = 0.0018
#
# phi = 18 *mm
# s = 200 * mm
# Out:
# $$
# \begin{aligned}
# h &= 600{,}0\ \mathrm{mm} \;
#  &b &= 1{,}0\ \mathrm{m} \;
#  &\rho &= 0{,}0 \;
# \\
#  \phi &= 18{,}0\ \mathrm{mm} \;
#  &s &= 200{,}0\ \mathrm{mm} \;
# \end{aligned}
# $$

# %%
# %%render 4
#
# A_s_min = b * h * rho
#
# A_s = (pi * (phi)**2 / 4)
#
# #As en mm2/m
# A_s_mm2_per_m = (A_s / s) * 1*m
# Out:
# $$
# \begin{aligned}
# A_{s_{min}} &= b \cdot h \cdot \rho  = 1{,}0000\ \mathrm{m} \cdot 600{,}0000\ \mathrm{mm} \cdot 0{,}0018 &= 1080{,}0000\ \mathrm{mm}^{2}
# \\
# A_{s} &= \left( \pi \cdot \frac{ \left( \phi \right) ^{ 2 } }{ 4 } \right)  = \left( 3{,}1416 \cdot \frac{ \left( 18{,}0000\ \mathrm{mm} \right) ^{ 2 } }{ 4 } \right) &= 254{,}4690\ \mathrm{mm}^{2}
# \\
# A_{s_{mm2_{per_{m}}}} &= \left( \frac{ A_{s} }{ s } \right) \cdot 1 \cdot m  = \left( \frac{ 254{,}4690\ \mathrm{mm}^{2} }{ 200{,}0000\ \mathrm{mm} } \right) \cdot 1 \cdot m &= 1272{,}3450\ \mathrm{mm}^{2}
# \end{aligned}
# $$

# %%
# %%render
#
# if A_s_min > A_s_mm2_per_m: check = "As menor que Asmin, AUMENTAR As"
#
# elif A_s_min < A_s_mm2_per_m: check = "As mayor que Asmin, OK"
# Out:
# $$
# \begin{aligned}
# &\text{Since, } A_{s_{min}} \lt A_{s_{mm2_{per_{m}}}} \rightarrow \left( 1080{,}000\ \mathrm{mm}^{2} \lt 1272{,}345\ \mathrm{mm}^{2} \right) :   \\
# \mathrm{check} &= \mathrm{As mayor que Asmin, OK} \;
# \end{aligned}
# $$

# %% [markdown]
# # A_v Sección Hormigón

# %%
# %%render params 2
#
# h = 600 * mm
# b = 1000 * mm
# r = 50 * mm
# d = h - r
#
# f_c = 30 * MPa
# Out:
# $$
# \begin{aligned}
# h &= 600{,}00\ \mathrm{mm} \;
#  &b &= 1{,}00\ \mathrm{m} \;
#  &r &= 50{,}00\ \mathrm{mm} \;
# \\
#  d &= 550{,}00\ \mathrm{mm} \;
#  &f_{c} &= 30{,}00\ \mathrm{MPa} \;
# \end{aligned}
# $$

# %%
# %%render 2
#
# V_c = 0.17 * sqrt(f_c) * b * d * MPa
# phi = 0.75
# V_c_phi = phi * V_c
#
# V_u = 160 * kN
#
# if V_u > V_c_phi: check = "Vu mayor que Vc, REQUIERE Vs"
# elif V_u < V_c_phi: check = "Vu menor que Vc, NO REQUIERE Vs"
# Out:
# $$
# \begin{aligned}
# V_{c} &= 0{,}17 \cdot \sqrt { f_{c} } \cdot b \cdot d \cdot \mathrm{MPa}  = 0{,}17 \cdot \sqrt { 30{,}00\ \mathrm{MPa} } \cdot 1{,}00\ \mathrm{m} \cdot 550{,}00\ \mathrm{mm} \cdot MPa &= 512{,}12\ \mathrm{kN}
# \\
# \phi &= 0{,}75 \;
# \\
# V_{c_{\phi}} &= \phi \cdot V_{c}  = 0{,}75 \cdot 512{,}12\ \mathrm{kN} &= 384{,}09\ \mathrm{kN}
# \\
# V_{u} &= 160 \cdot \mathrm{kN}  = 160 \cdot kN &= 160{,}00\ \mathrm{kN}
# \\
# &\text{Since, } V_{u} \lt V_{c_{\phi}} \rightarrow \left( 160{,}00\ \mathrm{kN} \lt 384{,}09\ \mathrm{kN} \right) :   \\
# \mathrm{check} &= \mathrm{Vu menor que Vc, NO REQUIERE Vs} \;
# \end{aligned}
# $$
