# %%
import handcalcs.render
from handcalcs import render
handcalcs.set_option("display_precision", 3)
handcalcs.set_option("decimal_separator", ",")
from handcalcs.decorator import handcalc

from math import pi, sqrt, sin, cos, tan, atan, tanh, cosh, sinh
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle, FancyBboxPatch
import matplotlib.patches as mpatches

import forallpeople
forallpeople.environment('structural', top_level=True)

# Configuración para gráficos export-ready
plt.rcParams['figure.dpi'] = 150
plt.rcParams['savefig.dpi'] = 300
plt.rcParams['font.size'] = 10
plt.rcParams['axes.labelsize'] = 11
plt.rcParams['axes.titlesize'] = 12
plt.rcParams['legend.fontsize'] = 9
plt.rcParams['figure.titlesize'] = 13

# %%
# %%render params
#
# D = 10 *m
# H = 9 *m
# V = pi*D**2/4*H
# r = 1 *m
# H_s = H + r
# G = 1
# T = 40
# F_y = 250 * MPa
# E_s = 200 * GPa
# Out:
# $$
# \begin{aligned}
# D &= 10{,}000\ \mathrm{m} \;
#  &H &= 9{,}000\ \mathrm{m} \;
#  &V &= 706{,}858\ \mathrm{m}^{3} \;
# \\
#  r &= 1{,}000\ \mathrm{m} \;
#  &H_{s} &= 10{,}000\ \mathrm{m} \;
#  &G &= 1 \;
# \\
#  T &= 40 \;
#  &F_{y} &= 250{,}000\ \mathrm{MPa} \;
#  &E_{s} &= 200{,}000\ \mathrm{GPa} \;
# \\
# \end{aligned}
# $$

# %%
# %%render params
#
# CA_t = 2 *mm
# CA_m = 2 *mm
# CA_f = 2 *mm
# Out:
# $$
# \begin{aligned}
# \mathrm{CA}_{t} &= 2{,}000\ \mathrm{mm} \;
#  &\mathrm{CA}_{m} &= 2{,}000\ \mathrm{mm} \;
#  &\mathrm{CA}_{f} &= 2{,}000\ \mathrm{mm} \;
# \\
# \end{aligned}
# $$

# %%
# %%render params
#
# A_0 = 0.4
# I = 1.0
# R = 4
