# %%
import handcalcs.render
from handcalcs import render
handcalcs.set_option("display_precision", 3)
handcalcs.set_option("decimal_separator", ",")
from handcalcs.decorator import handcalc

from math import pi, sqrt, sin, cos, tan, atan, tanh, cosh, sinh
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle, FancyBboxPatch
import matplotlib.patches as mpatches

import forallpeople
forallpeople.environment('structural', top_level=True)

# Configuración para gráficos export-ready
plt.rcParams['figure.dpi'] = 150
plt.rcParams['savefig.dpi'] = 300
plt.rcParams['font.size'] = 10
plt.rcParams['axes.labelsize'] = 11
plt.rcParams['axes.titlesize'] = 12
plt.rcParams['legend.fontsize'] = 9
plt.rcParams['figure.titlesize'] = 13

# %% [markdown]
# Esfuerzos del análisis sísmico

# %%
# %%render params 2
#
# V_base = 3.25 *MN
# M_base = 14.47 *MN * m
# M_volcante = 18.57 *MN * m
# Out:
# $$
# \begin{aligned}
# V_{base} &= 3{,}25\ \mathrm{MN} \;
#  &M_{base} &= 14{,}47\ \mathrm{MN} \cdot \mathrm{m} \;
#  &M_{volcante} &= 18{,}57\ \mathrm{MN} \cdot \mathrm{m} \;
# \\
# \end{aligned}
# $$

# %% [markdown]
# Pernos de Anclaje

# %%
# %%render 2
#
# n_pernos = 36
# V_corte_perno = V_base / (n_pernos / 3)  # Solo 1/3 de los pernos trabajan a corte
# Out:
# $$
# \begin{aligned}
# n_{pernos} &= 36 \;
# \\
# V_{corte_{perno}} &= \frac{ V_{base} }{ \frac{ n_{pernos} }{ 3 } }  = \frac{ 3{,}25\ \mathrm{MN} }{ \frac{ 36 }{ 3 } } &= 270{,}83\ \mathrm{kN} \; \;\textrm{(Solo 1/3 de los pernos trabajan a corte)}
# \end{aligned}
# $$

# %% [markdown]
# # Pernos de Anclaje

# %%
inch = 25.4 * mm

# %%
# %%render 2
#
# d_perno = 1.25 * inch
# n_hilos = 7
# A_perno = pi / 4 * (d_perno - 0.9743*inch / n_hilos)**2
#
# f_y = 250 * MPa
# f_u = 400 * MPa
# Out:
# $$
# \begin{aligned}
# d_{perno} &= 1{,}25 \cdot \mathrm{inch}  = 1{,}25 \cdot 25{,}40\ \mathrm{mm} &= 31{,}75\ \mathrm{mm}
# \\
# n_{hilos} &= 7 \;
# \\
# A_{perno} &= \frac{ \pi }{ 4 } \cdot \left( d_{perno} - 0{,}9743 \cdot \frac{ \mathrm{inch} }{ n_{hilos} } \right) ^{ 2 }  = \frac{ 3{,}14 }{ 4 } \cdot \left( 31{,}75\ \mathrm{mm} - 0{,}9743 \cdot \frac{ 25{,}40\ \mathrm{mm} }{ 7 } \right) ^{ 2 } &= 625{,}23\ \mathrm{mm}^{2}
# \\
# f_{y} &= 250 \cdot \mathrm{MPa}  = 250 \cdot MPa &= 250{,}00\ \mathrm{MPa}
# \\
# f_{u} &= 400 \cdot \mathrm{MPa}  = 400 \cdot MPa &= 400{,}00\ \mathrm{MPa}
# \end{aligned}
# $$

# %% [markdown]
# ## Tracción (ASD)

# %%
# %%render 2
#
# N_u = 290/2 * kN
#
# N_sa = A_perno * f_u
# Omega = 2
#
# FU_traccion = N_u / (N_sa / Omega)
# Out:
# $$
# \begin{aligned}
# N_{u} &= \frac{ 290 }{ 2 } \cdot \mathrm{kN}  = \frac{ 290 }{ 2 } \cdot kN &= 145{,}00\ \mathrm{kN}
# \\
# N_{sa} &= A_{perno} \cdot f_{u}  = 625{,}23\ \mathrm{mm}^{2} \cdot 400{,}00\ \mathrm{MPa} &= 250{,}09\ \mathrm{kN}
# \\
# \Omega &= 2 \;
# \\
# \mathrm{FU}_{traccion} &= \frac{ N_{u} }{ \frac{ N_{sa} }{ \Omega } }  = \frac{ 145{,}00\ \mathrm{kN} }{ \frac{ 250{,}09\ \mathrm{kN} }{ 2 } } &= 1{,}16
# \end{aligned}
# $$

# %% [markdown]
# ## Corte (ASD)

# %% [markdown]
# Se consideran llaves de corte en cada apoyo
