# %%
import handcalcs.render
from handcalcs import render
handcalcs.set_option("display_precision", 3)
handcalcs.set_option("decimal_separator", ",")
from handcalcs.decorator import handcalc

from math import pi, sqrt, sin, cos, tan, atan, tanh, cosh, sinh
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle, FancyBboxPatch
import matplotlib.patches as mpatches

import forallpeople
forallpeople.environment('structural', top_level=True)

# Configuración para gráficos export-ready
plt.rcParams['figure.dpi'] = 150
plt.rcParams['savefig.dpi'] = 300
plt.rcParams['font.size'] = 10
plt.rcParams['axes.labelsize'] = 11
plt.rcParams['axes.titlesize'] = 12
plt.rcParams['legend.fontsize'] = 9
plt.rcParams['figure.titlesize'] = 13

# %%
from handcalcs.decorator import handcalc

@handcalc()
def my_calc(x: float, y: float, z: float) -> float:
    a = 2*x
    b = 3 * a / z + sqrt(a + y /2)
    c = a + b
    return c

# %%
latex_code, result = my_calc(5, 10, 2)

# %%
print("LaTeX code:")
print(latex_code)
# Out:
# LaTeX code:
# $$
# \begin{aligned}
# a &= 2 \cdot x  = 2 \cdot 5 &= 10
# \\
# b &= 3 \cdot \frac{ a }{ z } + \sqrt { a + \frac{ y }{ 2 } }  = 3 \cdot \frac{ 10 }{ 2 } + \sqrt { 10 + \frac{ 10 }{ 2 } } &= 18{,}873
# \\
# c &= a + b  = 10 + 18{,}873 &= 28{,}873
# \end{aligned}
# $$

# %%
print(result)
# Out:
# 28.872983346207416

# %%
@handcalc(jupyter_display=True)
def my_calc(x: float, y: float, z: float) -> float:
    a = 2*x
    b = 3 * a / z + sqrt(a + y /2)
    c = a + b
    return c

# %%
result = my_calc(5, 10, 2)
# Out:
# $$
# \begin{aligned}
# a &= 2 \cdot x  = 2 \cdot 5 &= 10
# \\
# b &= 3 \cdot \frac{ a }{ z } + \sqrt { a + \frac{ y }{ 2 } }  = 3 \cdot \frac{ 10 }{ 2 } + \sqrt { 10 + \frac{ 10 }{ 2 } } &= 18{,}873
# \\
# c &= a + b  = 10 + 18{,}873 &= 28{,}873
# \end{aligned}
# $$

# %%
result = my_calc(50, 3, 2)
# Out:
# $$
# \begin{aligned}
# a &= 2 \cdot x  = 2 \cdot 50 &= 100
# \\
# b &= 3 \cdot \frac{ a }{ z } + \sqrt { a + \frac{ y }{ 2 } }  = 3 \cdot \frac{ 100 }{ 2 } + \sqrt { 100 + \frac{ 3 }{ 2 } } &= 160{,}075
# \\
# c &= a + b  = 100 + 160{,}075 &= 260{,}075
# \end{aligned}
# $$
